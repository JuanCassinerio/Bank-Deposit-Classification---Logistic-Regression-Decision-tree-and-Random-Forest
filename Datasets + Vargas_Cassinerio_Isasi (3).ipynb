# %%
# Los siguientes son los 3 dataset analizados

# %%
#DATASET PROPUESTA #5 Banking_Dataset_Classification
#Se importa libreria Pandas y se lee archivo new_train.csv
import pandas as pd
df = pd.read_csv('new_train.csv')
df.head(5)
# Out:
#    age           job   marital          education  default housing loan  \
# 0   49   blue-collar   married           basic.9y  unknown      no   no
# 1   37  entrepreneur   married  university.degree       no      no   no
# 2   78       retired   married           basic.4y       no      no   no
# 3   36        admin.   married  university.degree       no     yes   no
# 4   59       retired  divorced  university.degree       no      no   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0   cellular   nov         wed       227         4    999         0
# 1  telephone   nov         wed       202         2    999         1
# 2   cellular   jul         mon      1148         1    999         0
# 3  telephone   may         mon       120         2    999         0
# 4   cellular   jun         tue       368         2    999         0
#
#       poutcome    y
# 0  nonexistent   no
# 1      failure   no
# 2  nonexistent  yes
# 3  nonexistent   no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          32950 non-null  int64
#  1   job          32950 non-null  object
#  2   marital      32950 non-null  object
#  3   education    32950 non-null  object
#  4   default      32950 non-null  object
#  5   housing      32950 non-null  object
#  6   loan         32950 non-null  object
#  7   contact      32950 non-null  object
#  8   month        32950 non-null  object
#  9   day_of_week  32950 non-null  object
#  10  duration     32950 non-null  int64
#  11  campaign     32950 non-null  int64
#  12  pdays        32950 non-null  int64
#  13  previous     32950 non-null  int64
#  14  poutcome     32950 non-null  object
#  15  y            32950 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 4.0+ MB

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.014112    258.127466      2.560607    962.052413      0.174719
# std       10.403636    258.975917      2.752326    187.951096      0.499025
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    103.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000

# %%
df.shape
# Out:
# (32950, 16)

# %%
# ESTE DATASET FUE TOMADO DE LA WEB kaggle. https://www.kaggle.com/datasets/rashmiranu/banking-dataset-classification

# Este DataSet estudia la posibilidad de que un cliente de un banco se subcriba a realizar un depósito a plazo

# Tomando en cuenta age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, 
# pdays, previous, poutcome 

# age: edad del cliente
# job: profesion ('admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# marital: estado civil 
# education: formacion academica ('basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# default: si posee credito defaulteado ('no','yes','unknown')
# housing: si posee credito inmobiliario ('no','yes','unknown')
# loan: si posee un credito personal ('no','yes','unknown')
# contact: metodo de contacto ('cellular','telephone')
# month: ultimo mes de contacto realizado al cliente durante la campaña de marketing ('jan', 'feb', 'mar', …, 'nov', 'dec')
# day_of_week: ultimo contacto de la semana ('mon','tue','wed','thu','fri')
# duration: duracion del ultimo contacto en dicha llamada, en segundos
# campaign: numero de contactos realizados durante esta ultima campaña
# pdays: numero de dias que pasaron desde la ultima vez que fue contactado (999 means client was not previously contacted)
# previous: numero de contactos realizados a este cliente antes de la presente campaña
# poutcome: resultado de la campaña ('failure','nonexistent','success')
     
# La variable a predecir es y donde 1: se subscribio 0: no se subscribio.

# Este analisis servira para verificar si una persona sera propensa a realizar un depósito a plazo. Se buscara realizar un 
# algoritmo con ML(logistic regression, desicion tree, random forest) pora realizar esta predicción.

# %%
## DATASET PROPUESTA#3 Airline_Delays_Weather_and_Airport_Detail

#Se importa libreria Pandas y se lee archivo csv en disco local. df Airline_Delays_Weather_and_Airport_Detail
import pandas as pd
df = pd.read_csv('full_data_flightdelay.csv')
df.head(5)
# Out:
#    MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  SEGMENT_NUMBER  \
# 0      1            7          0    0800-0859               2               1
# 1      1            7          0    0700-0759               7               1
# 2      1            7          0    0600-0659               7               1
# 3      1            7          0    0600-0659               9               1
# 4      1            7          0    0001-0559               7               1
#
#    CONCURRENT_FLIGHTS  NUMBER_OF_SEATS            CARRIER_NAME  \
# 0                  25              143  Southwest Airlines Co.
# 1                  29              191    Delta Air Lines Inc.
# 2                  27              199    Delta Air Lines Inc.
# 3                  27              180    Delta Air Lines Inc.
# 4                  10              182        Spirit Air Lines
#
#    AIRPORT_FLIGHTS_MONTH  ...  PLANE_AGE       DEPARTING_AIRPORT  LATITUDE  \
# ...

# %%
# Se muestra informacion de tipo de datos existentes en el DF y tañamo del archivo.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
#Se muestra descripcion estaditicas de df. conteo,media, desviacion estandar,
# mediana,promedio y percentiles 25%, 50%, 75% y max. 
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df.shape
# Out:
# (148670, 34)

# %%
print(df.isnull().sum())
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
# ESTE DATASET FUE TOMADO DE LA WEB kaggle. https://www.kaggle.com/datasets/threnjen/2019-airline-delays-and-cancellations

# Este DataSet estudia la posibles demoras que pueden exitir segun el historico de vuelos realizados por varias aerolineas
#  tomando en cuenta el clima, vuelos actuales, salida del vuelo, tiempo de planificacion, numero de asientos entre otras.

# Variable a predecir seria DEP_DEL15. 1: Demorado 0: Sin demora.

# AIRPORT_FLIGHTS_MONTH: Muestra el promedio de vuelos por mes en el aeropuerto.

# CARRIER_NAME: Aerolinea que esta operando el vuelo.

# NUMBER_OF_SEATS: Numero de puestos que tiene el avion en cuestion.

# CONCURRENT_FLIGHTS: Cantidad de vuelos despegando en el mismo bloque de tiempo.

# DEP_TIME_BLK: Rango de distancia que volará la aeronave para llegar a destino.

# DAY_OF_WEEK: Dia de la semana que se realiza el vuelo.

# Ese analisis serviria para verificar si un vuelo es propenso a demorarse y lograr evitar que pase a futuro. El objetivo seria
#  crear un algoritmo de Clasificacion con ML para lograr definir la demora.

# %%
#DATASET PROPUESTA #6 Loan Default Dataset
import pandas as pd
df = pd.read_csv('Loan_Default.csv')
df.head(5)
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                  nob/c
# 1           p1                l1        nopc                    b/c
# 2           p1                l1        nopc                  nob/c
# 3           p4                l1        nopc                  nob/c
# 4           p1                l1        nopc                  nob/c
#
#    loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df.shape
# Out:
# (148670, 34)

# %%
print(df.isnull().sum())
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
#La finalidad del dataset es lograr predecir si un prestamo será pagado o no lo será mediante la utilización de herramientas de ML

#ID:ID del dato, valor único Indice
#Año:year  Año de aplicación
#Limite de Crédito: loan_limit limite de credito de la persona 
#Sexo: Gender Sexo del solicitante 
#Preaprobado: approv_in_adv  si el crédito fue preaprobada o no lo fue
#Tipo de Crédito: loan_type  tipología de Crédito
#Propopisto del crédito: loan_purpose Proposito del crédito
#Solvencia: Credit_Worthiness Solvencia de la persona
#Credito abierto: open_credit Si el crédito se encuentra abierto o no lo está
#Comercial o de negocio:business_or_commercial Tipo de credito, comercial o de negocio
#Monto del crédito: loan_amount Monto del credito en valor monetario
#Tasa de Interes:rate_of_interest Tasa de interes del crédito
#Spred:Interest_rate_spread Spread Spread bancario
#Cargos de anticipo:Upfront_charges Cargos por anticipo del préstamo (adelantar cuotas)
#Plazo: term  Duración del crédito
#Amortización: Neg_ammortization Amortización negativa (pagar menos que los intereses generados)
#unicamente interes: interest_only 
#Adelantar pagos: lump_sum_payment posibilidad de adelant pagos
#Valor de la propiedad:property_value  Valor de la propiedad la cual se adquirirá con el crédito
#Tipo de construcción: construction_type Tipo de construción a la cual fue otorgada el crédito
#Tipo de ocupación: occupancy_type  Tipo de ocupación (vivienda o inversión)
#Asegurada por: Secured_by Asegurada para
#Ingreso:income Ingreso del solicitante 
#Tipo de Crédito:credit_type Tipo de credito a solicitar 
#Puntuación Crediticia:Credit_Score Puntuación crediticia obtenida
#Co Aplicante: co-applicant_credit_type 
#Edad:age Edad del solicitante
#Presentación de la aplicación:  submission_of_application si se presentó una aplicación
#Relación prestamo/precio:LTV   Relación entre el valor del préstamo y el valor de la vivienda 
#Región: Region  Region donde se solicita 
#Tipo de Seguridad: Security_Type Garantía
#Deuda sobre ingresos: dtir1  cantidad de deuda sobre el ingreso 
#Total de Unidades: total_units numero de unidades en una casa

#Estado: Status Estado del crédito ----Objetivo----"""
